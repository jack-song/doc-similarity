# %%
# built-in libs
import os
from pathlib import Path

# obsidiantools requirements
import numpy as np
import pandas as pd
import networkx as nx

# extra libs for this notebook (visualise graph)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
VAULT_DIR = Path("/Users/jacksong/Library/Mobile Documents/iCloud~md~obsidian/Documents/Incredex")

# %%
import obsidiantools.api as otools  # api shorthand

# %%
vault = otools.Vault(VAULT_DIR).connect().gather()

# %%
print(f"Connected?: {vault.is_connected}")
print(f"Gathered?:  {vault.is_gathered}")
# Out:
# Connected?: True
# Gathered?:  True

# %% [markdown]
# ### 1. What files do I have in my vault?

# %%
import docsim
docsim_obj = docsim.DocSim(verbose=True)

def get_full_text(name):
    return name + '. ' + vault.get_text(name)

documents = {name: get_full_text(name) for name in vault.file_index.keys()}

print(docsim_obj.top_pairs(documents))
# Out:
# Loading default GloVe word vector model: glove-wiki-gigaword-50
# Model loaded
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ps/k24lbqvs5q11gxbg_qhzykz40000gn/T/ipykernel_92970/1083160225.py in <module>
#       7 documents = {name: get_full_text(name) for name in vault.file_index.keys()}
#       8
# ----> 9 print(docsim_obj.top_pairs(documents))
#
# ~/per/doc-similarity/docsim.py in top_pairs(self, keyToDoc)
#     372             doc_vecs = self.tfidf[
#     373                 [self.dictionary.doc2bow(document) for document in corpus]
# --> 374             ]
#     375             single_doc_vecs = [
#     376                 self.tfidf[self.dictionary.doc2bow(document)] for document in corpus
#
# NameError: name 'documents' is not defined

# %% [markdown]
# If you want to filter on subdirectories, you can do so like this:

# %%
(otools.Vault(VAULT_DIR, include_subdirs=['lipsum'], include_root=False)
 .file_index)
# Out:
# {}

# %% [markdown]
# ### 2. Which notes are 'isolated' in my vault?

# %% [markdown]
# In graph analysis, nodes are **isolated** if they do not connect to other nodes in a graph.  Each NOTE in your vault in graph terminology is a node.
#
# In the Obsidian world, what does it mean for notes to be isolated?
#
# **Isolated notes** have **no backlinks** AND **no wikilinks**.

# %%
vault.isolated_notes
# Out:
# ['Marketing Learning',
#  'Promote healthy living habits on tiktok',
#  'Game World Design',
#  'Reputable social overlay on the internet',
#  'Communication and Emotional Improvement',
#  'Heat Pumps',
#  'Ilumivu Team',
#  'Self Halo',
#  'I can just ask for things and be excited about them',
#  'Moka Pot',
#  'Ilumivu Combined Meeting',
#  'AGN Working Team',
#  'Neighbourhood set',
#  'Eletricity',
#  'TikTok is really bad',
#  'Strategy and decisions',
#  'HCC Investors',
#  'Choosing between different email verification providers',
#  'Reading List',
#  'One Man Architectures',
#  'Limitations of Acts of Service',
#  'Maturity As Children',
#  'Git PAT',
#  'Photography',
#  'Project Success',
#  'GEB',
#  'Short Term Monetization Planning',
#  'Perfect Day',
#  'Rohan',
#  'A new search',
#  'The benefits of walking',
#  'Small tasks',
#  'Grease the groove',
#  'Food Tricks',
#  'Need to read documentation thoroughly',
#  "Linda can't get paid through upwork",
#  'DD Cardiogram',
#  'Geometric Game AI',
#  'Talking with Linda',
#  'Trying Psilocybin',
#  'Meetings with Harish',
#  'Raghubir Singh',
#  'Ilumivu goals by January 31',
#  'Blender Low Poly Tricks',
#  'Feedback for Tom',
#  'Personal Brand and Persona',
#  'Kotlin quirks',
#  'Eink Browser',
#  'Financial Updates',
#  'How total war can be improved',
#  'Kingrinder K4',
#  'Teflon is an example of perverse corporate action',
#  'TikTok is great for building a young audience',
#  'Clarify context before giving feedback',
#  'Online enlightenment salons',
#  'Good habits come from generosity and strong rails',
#  'Marketing Agency Decision',
#  'Sperm Whale Facts',
#  'The General Commands',
#  'Setting Growth Goals',
#  'Reference Google Engine',
#  'Naval',
#  'Working With Tom',
#  'CX Meetings',
#  'Ancient Autometa',
#  'ACW Portable Wargame Variant',
#  'Andy Tech Setup',
#  'Climate Crisis',
#  'Buy and Shopping list',
#  'Working Commitment',
#  'How to schedule and prioritize work appropriately',
#  'Cardiogram but better',
#  'DNS Personal retro',
#  'Korean',
#  'I can enjoy helping others have fun',
#  'Startup Funding',
#  'Illumivu Marketing Kickoff',
#  'Merger Aftermath',
#  'Test Tracks',
#  'Purchase Checklist',
#  'Email Security',
#  'Colors',
#  'Dishwashers',
#  'AGN Marketing Kickoff',
#  'Legal "Requirements"',
#  "Tom's hiring process",
#  'Modern Skirmish Wargame Rules',
#  'Lin Manuel Miranda appeals to the modern everyman',
#  'Document similarity is a multi-stage process',
#  'Evil Lobbying',
#  'VP Engineering Books',
#  'Mango and mayo in shrimp tacos',
#  'Once a day apps',
#  'XGBoost',
#  'The democratic process is weak',
#  'Testing an ML Model',
#  'Procrastination Monkey',
#  'Online monetization without ads',
#  'Wabi Sabi',
#  'Alan',
#  'Talking With Harish',
#  'Linda',
#  'Going on trips',
#  'Management Culture',
#  'Anonymized ML training',
#  'How to upgrade small talk',
#  'When Hurt by Someone',
#  'Piano',
#  'Mark Tech Gee Whiz Meetings',
#  'Camping Shit',
#  'Web and Marketing',
#  '3D Print Figures',
#  'Python Shit',
#  'Bill Bates',
#  "It's very hard to understand how to contribute to causes I believe in",
#  'Foaming Milk',
#  'Stuff to 3D pPrint',
#  'Cardiogram Marketing',
#  'The perfect design in yin yang',
#  'Linking notes is easier with a multi-note interface',
#  'Perfect House',
#  'Leanplum',
#  'If tests are failing or changing behavior based on order they run in.',
#  'Espresso makes bad beans taste better',
#  '3D Print Design Ideas',
#  'Sapolsky says human behavior is determined on a spectrum of time and sources',
#  'Continued Merger Meetings',
#  'Ilumivu closing',
#  'Build an engaged work environment',
#  'Positivity',
#  'Top of mind dev support resources',
#  'Public APIs and Data',
#  'Board Games',
#  'Using Obsidian as CMS and publishing easier and faster',
#  'Ilumivu Marketing Meeting',
#  'Project Strategies',
#  'War Profiteering',
#  'Setting up Github for an Old Project',
#  'blue jay',
#  'Subitize',
#  'Low code is causing websites and apps to converge',
#  "David Li's Missisauga Address",
#  'Startup Culture',
#  'Watch List',
#  'HyperPortable Hangboards',
#  'Hiring At Ilumivu',
#  'Starting a campfire takes more tinder and kindling than expected',
#  'Castle Ravenloft',
#  'Ilumivu business sales learnings',
#  'Anxious Ambivalent Avoidant Attachment',
#  'Managing Python Stuff',
#  'Air Conditioning',
#  'Designing Data Intensive Applications',
#  'Baking Pizza',
#  'Try making my home page query oriented',
#  'Double Standards',
#  'Jordan Peterson',
#  'Working with Tom Hiring',
#  'Tom Hiring',
#  'Random things to look up',
#  'Coding Basics',
#  'Youtube science debates',
#  'Purpose',
#  'Health EHeart Meeting',
#  'Ilumivu Study Plan',
#  'Leslie Foods',
#  'Fictional romances',
#  'DNS retro',
#  'Catch Up Interview',
#  '3D Print Board Games',
#  'My Relationship Compatibility',
#  'A16Z',
#  'Book First Lines',
#  "You don't know yourself until you write it down",
#  'Correct PM Behavior',
#  'Georgia is taking on Hollywood',
#  'General software architecture concepts',
#  'Leaders help proactively',
#  'Personality Change',
#  'More Ilumivu Meetings',
#  'Sides of Stories',
#  'Young people struggle with basic life mechanics',
#  'Meeting with Sandeep on Offer',
#  'Design Review',
#  'Pattio',
#  'Dream about flying through a pokemon world',
#  'Final fantasy password',
#  'Founder Material',
#  'Engineering leaders can serve the rest of the company',
#  'Disaster Recovery',
#  'Backlog of things to do',
#  'Software Books',
#  'Cardiogram Premium Conversion',
#  'Dubai',
#  'New Numbers Ilumivu',
#  'Meta Rules Game AI',
#  'Farmland being bought up',
#  "Cardiogram can't manage to sell its value",
#  'Hiring John Norback',
#  'Always configure auto setup for terminal tools',
#  'John Norback',
#  'Balancing a game with diverse actions and units',
#  'Harish',
#  'My computer setup',
#  'How to Effectively Test Product Hypotheses',
#  'Doing art fast',
#  'Aversion to Account Making',
#  'Influence, Corporations, and Trust',
#  'Important data lake parameters',
#  'Leslie',
#  'DD SAGE',
#  'Dark roasts need lower temp water, coarser grind, and shorter ratio',
#  'Unfocused design is bad design',
#  'Cognitive Dissonance during arguments',
#  'Just write it out',
#  'Management Meetings',
#  'Working Hard',
#  'A proper support ticketing system is important',
#  'Meeting With Sandeep',
#  'My habit guidance',
#  'Weaknessess',
#  'Purchase Log',
#  'Artists to Copy',
#  'Immune System',
#  'Process improvements should be migrated lazily',
#  'Leslie Music',
#  'DD mEMA',
#  'Manuel',
#  "House of Java's espresso is not good",
#  'Meat Industry Monopolies',
#  'Examples of Side Revenue',
#  'Heaters',
#  'Investing',
#  'Research needs to be spiked',
#  'Negotiating Employment with Ilumivu',
#  'General Management Tips',
#  'Cooking',
#  'GDPR',
#  'Leanplum Tracking User Events',
#  'People want what others want',
#  'Differential Diagnosis',
#  'ML Model selection',
#  'Flying Travel Packing',
#  'Stoicism',
#  'Robusta not neccessarily bad tasting',
#  'Maylynn',
#  'Ilumivu Engagement',
#  "Simpson's Paradox results in counter intuitive results",
#  'Try to get something out of every meeting']

# %% [markdown]
# In the Obsidian community these notes are often called 'orphan notes'.  This interface is sticking to graph analysis terminology; NetworkX calls the graph nodes 'isolates'.

# %% [markdown]
# ### 3. Which notes have I not got round to creating yet?

# %% [markdown]
# When you create wikilinks in your vault notes, you can create connections to notes that you haven't created yet.  This means that these new notes have backlinks and are displayed in your vault graph, but they don't exist as markdown files.
#
# In this interface these are called **nonexistent notes**.

# %%
vault.nonexistent_notes
# Out:
# ['RICE', 'Beyesian Reasoning', 'Black Swan', 'Mimicry']

# %% [markdown]
# ### 4. What are the notes that have the most backlinks?

# %% [markdown]
# The **`get_note_metadata`** method gives a summary of your vault's notes.
#
# You can see, for example:
# - Counts of backlinks (`n_backlinks`)
# - Counts of wikilinks (`n_wikilinks`)
# - Counts of embedded files (`n_embedded_files`)
# - Modified time (`modified_time`)
#
# Note: created time is available across all operating systems so that is not included.

# %%
df = vault.get_note_metadata()

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/ps/k24lbqvs5q11gxbg_qhzykz40000gn/T/ipykernel_92970/3771845804.py in <module>
# ----> 1 df.info()
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/frame.py in info(self, verbose, buf, max_cols, memory_usage, null_counts)
#    2272                         self.index._is_memory_usage_qualified()):
#    2273                     size_qualifier = '+'
# -> 2274             mem_usage = self.memory_usage(index=True, deep=deep).sum()
#    2275             lines.append("memory usage: {mem}\n".format(
#    2276                 mem=_sizeof_fmt(mem_usage, size_qualifier)))
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/frame.py in memory_usage(self, index, deep)
#    2366         if index:
#    2367             result = Series(self.index.memory_usage(deep=deep),
# -> 2368                             index=['Index']).append(result)
#    2369         return result
#    2370
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     273             else:
#     274                 data = _sanitize_array(data, index, dtype, copy,
# --> 275                                        raise_cast_failure=True)
#     276
#     277                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    4147
#    4148             subarr = construct_1d_arraylike_from_scalar(
# -> 4149                 value, len(index), dtype)
#    4150
#    4151         else:
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1199         if is_integer_dtype(dtype) and isna(value):
#    1200             dtype = np.float64
# -> 1201         subarr = np.empty(length, dtype=dtype)
#    1202         subarr.fill(value)
#    1203
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %% [markdown]
# Sort these notes by number of backlinks (descending order).

# %%
df.sort_values('n_backlinks', ascending=False)
# Out:
#   /Users/jacksong/Library/Mobile Documents/iClou...
# Testing an ML Model                                /Users/jacksong/Library/Mobile Documents/iClou...
# The democratic process is weak                     /Users/jacksong/Library/Mobile Documents/iClou...
# Coffee                                             /Users/jacksong/Library/Mobile Documents/iClou...
# Lin Manuel Miranda appeals to the modern everyman  /Users/jacksong/Library/Mobile Documents/iClou...
# Once a day apps                                    /Users/jacksong/Library/Mobile Documents/iClou...
# Mango and mayo in shrimp tacos                     /Users/jacksong/Library/Mobile Documents/iClou...
# VP Engineering Books                               /Users/jacksong/Library/Mobile Documents/iClou...
# Evil Lobbying                                      /Users/jacksong/Library/Mobile Documents/iClou...
# Subscriptions that I pay for                       /Users/jacksong/Library/Mobile Documents/iClou...
# Document similarity is a multi-stage process       /Users/jacksong/Library/Mobile Documents/iClou...
# Perfect House                                      /Users/jacksong/Library/Mobile Documents/iClou...
#
#                                                    note_exists  n_backlinks  \
# note
# Adjacent Opportunities                                    True            3
# One Habit Way                                             True            3
# Ikigai                                                    True            3
# Deep Work                                                 True            3
# Dharma                                                    True            3
# Incredex                                                  True            3
# Personalized web                                          True            2
# Mimicry                                                  False            2
# Human Condition                                           True            2
# You're not above the hype train                           True            2
# Black Swan                                               False            1
# The world is value based                                  True            1
# Engage good opportunities                                 True            1
# Suprising notes are creative notes                        True            1
# Borderline Personality Disorder                           True            1
# Flair                                                     True            1
# Niche online communities are blooming                     True            1
# Bird in the hand                                          True            1
# Tiers of effective learning                               True            1
# My Notes System                                           True            1
# Finding good working groups                               True            1
# hypotheses just aren't that important                     True            1
# Meta improvement is often a red herring                   True            1
# Othismos                                                  True            1
# build online presence                                     True            1
# Link Prediction                                           True            1
# The Book of Why                                           True            1
# Utility Software I use                                    True            1
# Word Embeddings                                           True            1
# ML Injection Attacks                                      True            1
# ...                                                        ...          ...
# Email Security                                            True            0
# Purchase Checklist                                        True            0
# Test Tracks                                               True            0
# Merger Aftermath                                          True            0
# Illumivu Marketing Kickoff                                True            0
# Startup Funding                                           True            0
# I can enjoy helping others have fun                       True            0
# Korean                                                    True            0
# DNS Personal retro                                        True            0
# Cardiogram but better                                     True            0
# How to schedule and prioritize work appropriately         True            0
# Legal "Requirements"                                      True            0
# Tom's hiring process                                      True            0
# Modern Skirmish Wargame Rules                             True            0
# XGBoost                                                   True            0
# Wabi Sabi                                                 True            0
# root                                                      True            0
# Online monetization without ads                           True            0
# Procrastination Monkey                                    True            0
# Testing an ML Model                                       True            0
# The democratic process is weak                            True            0
# Coffee                                                    True            0
# Lin Manuel Miranda appeals to the modern everyman         True            0
# Once a day apps                                           True            0
# Mango and mayo in shrimp tacos                            True            0
# VP Engineering Books                                      True            0
# Evil Lobbying                                             True            0
# Subscriptions that I pay for                              True            0
# Document similarity is a multi-stage process              True            0
# Perfect House                                             True            0
#
#                                                    n_wikilinks  \
# note
# Adjacent Opportunities                                     0.0
# One Habit Way                                              0.0
# Ikigai                                                     1.0
# Deep Work                                                  0.0
# Dharma                                                     1.0
# Incredex                                                   1.0
# Personalized web                                           0.0
# Mimicry                                                    NaN
# Human Condition                                            0.0
# You're not above the hype train                            0.0
# Black Swan                                                 NaN
# The world is value based                                   1.0
# Engage good opportunities                                  1.0
# Suprising notes are creative notes                         0.0
# Borderline Personality Disorder                            0.0
# Flair                                                      0.0
# Niche online communities are blooming                      0.0
# Bird in the hand                                           2.0
# Tiers of effective learning                                1.0
# My Notes System                                            1.0
# Finding good working groups                                5.0
# hypotheses just aren't that important                      1.0
# Meta improvement is often a red herring                    0.0
# Othismos                                                   0.0
# build online presence                                      0.0
# Link Prediction                                            1.0
# The Book of Why                                            1.0
# Utility Software I use                                     0.0
# Word Embeddings                                            0.0
# ML Injection Attacks                                       0.0
# ...                                                        ...
# Email Security                                             0.0
# Purchase Checklist                                         0.0
# Test Tracks                                                0.0
# Merger Aftermath                                           0.0
# Illumivu Marketing Kickoff                                 0.0
# Startup Funding                                            0.0
# I can enjoy helping others have fun                        0.0
# Korean                                                     0.0
# DNS Personal retro                                         0.0
# Cardiogram but better                                      0.0
# How to schedule and prioritize work appropriately          0.0
# Legal "Requirements"                                       0.0
# Tom's hiring process                                       0.0
# Modern Skirmish Wargame Rules                              0.0
# XGBoost                                                    0.0
# Wabi Sabi                                                  0.0
# root                                                       6.0
# Online monetization without ads                            0.0
# Procrastination Monkey                                     0.0
# Testing an ML Model                                        0.0
# The democratic process is weak                             0.0
# Coffee                                                     2.0
# Lin Manuel Miranda appeals to the modern everyman          0.0
# Once a day apps                                            0.0
# Mango and mayo in shrimp tacos                             0.0
# VP Engineering Books                                       0.0
# Evil Lobbying                                              0.0
# Subscriptions that I pay for                               1.0
# Document similarity is a multi-stage process               0.0
# Perfect House                                              0.0
#
#                                                    n_embedded_files  \
# note
# Adjacent Opportunities                                          0.0
# One Habit Way                                                   0.0
# Ikigai                                                          0.0
# Deep Work                                                       0.0
# Dharma                                                          0.0
# Incredex                                                        0.0
# Personalized web                                                0.0
# Mimicry                                                         NaN
# Human Condition                                                 0.0
# You're not above the hype train                                 0.0
# Black Swan                                                      NaN
# The world is value based                                        0.0
# Engage good opportunities                                       0.0
# Suprising notes are creative notes                              0.0
# Borderline Personality Disorder                                 0.0
# Flair                                                           0.0
# Niche online communities are blooming                           0.0
# Bird in the hand                                                0.0
# Tiers of effective learning                                     0.0
# My Notes System                                                 0.0
# Finding good working groups                                     0.0
# hypotheses just aren't that important                           0.0
# Meta improvement is often a red herring                         0.0
# Othismos                                                        0.0
# build online presence                                           0.0
# Link Prediction                                                 0.0
# The Book of Why                                                 0.0
# Utility Software I use                                          0.0
# Word Embeddings                                                 0.0
# ML Injection Attacks                                            0.0
# ...                                                             ...
# Email Security                                                  0.0
# Purchase Checklist                                              0.0
# Test Tracks                                                     0.0
# Merger Aftermath                                                0.0
# Illumivu Marketing Kickoff                                      0.0
# Startup Funding                                                 0.0
# I can enjoy helping others have fun                             0.0
# Korean                                                          0.0
# DNS Personal retro                                              0.0
# Cardiogram but better                                           0.0
# How to schedule and prioritize work appropriately               0.0
# Legal "Requirements"                                            0.0
# Tom's hiring process                                            0.0
# Modern Skirmish Wargame Rules                                   0.0
# XGBoost                                                         0.0
# Wabi Sabi                                                       0.0
# root                                                            0.0
# Online monetization without ads                                 0.0
# Procrastination Monkey                                          0.0
# Testing an ML Model                                             0.0
# The democratic process is weak                                  0.0
# Coffee                                                          0.0
# Lin Manuel Miranda appeals to the modern everyman               0.0
# Once a day apps                                                 0.0
# Mango and mayo in shrimp tacos                                  0.0
# VP Engineering Books                                            0.0
# Evil Lobbying                                                   0.0
# Subscriptions that I pay for                                    0.0
# Document similarity is a multi-stage process                    0.0
# Perfect House                                                   0.0
#
#                                                                   modified_time
# note
# Adjacent Opportunities                            2022-02-03 18:09:30.227800369
# One Habit Way                                     2022-02-03 16:58:57.232205391
# Ikigai                                            2021-08-06 16:16:00.939516306
# Deep Work                                         2022-02-03 18:16:58.706135035
# Dharma                                            2021-08-06 17:12:11.711994410
# Incredex                                          2022-02-02 17:30:45.218940020
# Personalized web                                  2022-02-09 16:57:37.591037273
# Mimicry                                                                     NaT
# Human Condition                                   2021-08-23 18:54:22.217773438
# You're not above the hype train                   2022-02-03 18:20:20.443877459
# Black Swan                                                                  NaT
# The world is value based                          2021-12-13 15:03:15.148470402
# Engage good opportunities                         2022-02-03 18:11:18.457508326
# Suprising notes are creative notes                2022-02-09 15:41:00.117903709
# Borderline Personality Disorder                   2021-08-23 17:09:32.754163742
# Flair                                             2022-02-02 15:42:48.725263357
# Niche online communities are blooming             2022-02-09 17:42:33.694370747
# Bird in the hand                                  2022-02-03 18:15:50.754984617
# Tiers of effective learning                       2022-02-02 16:28:44.839157820
# My Notes System                                   2022-02-02 15:55:02.809559584
# Finding good working groups                       2022-02-09 17:41:44.833650351
# hypotheses just aren't that important             2022-02-09 15:58:11.377122641
# Meta improvement is often a red herring           2022-02-09 17:23:25.808519363
# Othismos                                          2022-02-02 16:59:45.445080757
# build online presence                             2022-02-11 16:42:32.637129068
# Link Prediction                                   2022-02-16 16:08:41.299541473
# The Book of Why                                   2022-02-02 16:16:00.523168086
# Utility Software I use                            2022-01-30 14:51:07.180828094
# Word Embeddings                                   2021-12-16 17:18:49.573828697
# ML Injection Attacks                              2022-02-10 19:24:29.819618464
# ...                                                                         ...
# Email Security                                    2021-11-17 17:14:05.316294193
# Purchase Checklist                                2021-12-20 05:19:58.000000000
# Test Tracks                                       2021-08-30 16:34:54.971631765
# Merger Aftermath                                  2021-10-21 16:50:26.906132460
# Illumivu Marketing Kickoff                        2021-08-12 18:19:35.964480639
# Startup Funding                                   2021-08-17 07:02:50.967266083
# I can enjoy helping others have fun               2022-02-07 14:15:18.186336517
# Korean                                            2021-11-16 18:48:37.211620808
# DNS Personal retro                                2021-09-17 17:38:49.586757421
# Cardiogram but better                             2022-02-07 20:19:02.004349709
# How to schedule and prioritize work appropriately 2021-09-01 18:01:07.714826822
# Legal "Requirements"                              2021-10-05 18:34:10.856332302
# Tom's hiring process                              2022-02-01 16:30:21.873555660
# Modern Skirmish Wargame Rules                     2021-08-14 05:54:11.460234880
# XGBoost                                           2022-02-03 22:04:20.306463003
# Wabi Sabi                                         2021-08-30 16:11:54.985090971
# root                                              2022-02-14 16:43:04.296114445
# Online monetization without ads                   2022-02-09 15:16:23.583785534
# Procrastination Monkey                            2021-08-06 05:22:12.969536066
# Testing an ML Model                               2022-02-14 17:31:26.128184318
# The democratic process is weak                    2022-02-09 15:17:49.917767763
# Coffee                                            2022-02-04 15:56:55.345019579
# Lin Manuel Miranda appeals to the modern everyman 2022-02-03 17:34:05.216269255
# Once a day apps                                   2022-02-08 20:07:36.852310181
# Mango and mayo in shrimp tacos                    2022-02-06 15:51:18.155615091
# VP Engineering Books                              2021-08-14 05:55:50.150489569
# Evil Lobbying                                     2021-08-11 05:58:32.214877367
# Subscriptions that I pay for                      2022-02-07 18:37:42.304468393
# Document similarity is a multi-stage process      2022-02-08 18:01:35.069772959
# Perfect House                                     2021-11-23 01:22:57.666026354
#
# [337 rows x 7 columns]

# %% [markdown]
# We can see that **Bacchus** has the most backlinks.  It's actually a nonexistent note.

# %%
vault.get_backlinks('Bacchus')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ps/k24lbqvs5q11gxbg_qhzykz40000gn/T/ipykernel_92970/3587501273.py in <module>
# ----> 1 vault.get_backlinks('Bacchus')
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/obsidiantools/api.py in get_backlinks(self, note_name)
#     259
#     260         if note_name not in self._graph.nodes:
# --> 261             raise ValueError('"{}" not found in graph.'.format(note_name))
#     262         else:
#     263             return self._backlinks_index[note_name]
#
# ValueError: "Bacchus" not found in graph.

# %%
vault.get_backlink_counts('Bacchus')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ps/k24lbqvs5q11gxbg_qhzykz40000gn/T/ipykernel_92970/3812233215.py in <module>
# ----> 1 vault.get_backlink_counts('Bacchus')
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/obsidiantools/api.py in get_backlink_counts(self, note_name)
#     277
#     278         if note_name not in self._graph.nodes:
# --> 279             raise ValueError('"{}" not found in graph.'.format(note_name))
#     280         else:
#     281             backlinks = self.get_backlinks(note_name)
#
# ValueError: "Bacchus" not found in graph.

# %% [markdown]
# You can see all the backlinks in the `backlinks_index`.

# %%
vault.backlinks_index
# Out:
# {'Marketing Learning': [],
#  'Promote healthy living habits on tiktok': [],
#  'Game World Design': [],
#  'Reputable social overlay on the internet': [],
#  'Reading effectively': [],
#  'Communication and Emotional Improvement': [],
#  'Distribution is still king': ['Finding good working groups'],
#  'Heat Pumps': [],
#  'Ilumivu Team': [],
#  'Self Halo': [],
#  'I can just ask for things and be excited about them': [],
#  'Moka Pot': [],
#  'Ilumivu Combined Meeting': [],
#  'economic success is driven by channels and innovation equally': ["hypotheses just aren't that important"],
#  'AGN Working Team': [],
#  'Neighbourhood set': [],
#  'Eletricity': [],
#  'TikTok is really bad': [],
#  'Formwell': ['root'],
#  'Strategy and decisions': [],
#  'HCC Investors': [],
#  'innovation is iteration': ['economic success is driven by channels and innovation equally'],
#  'Choosing between different email verification providers': [],
#  'The web has been neutered in terms of personalized discovery': ['I tried querying about creativity and idea generation in a few gardens'],
#  'Document Similarity': ['NLP'],
#  'Cal Newport': ["So Good They Can't Ignore You"],
#  'Reading List': [],
#  'Alain De Botton': [],
#  'One Man Architectures': [],
#  'Limitations of Acts of Service': [],
#  'Maturity As Children': [],
#  'Git PAT': [],
#  'Photography': [],
#  'Project Success': [],
#  'GEB': [],
#  'Short Term Monetization Planning': [],
#  'Perfect Day': [],
#  'Rohan': [],
#  'A new search': [],
#  'The benefits of walking': [],
#  'Small tasks': [],
#  'Grease the groove': [],
#  'Food Tricks': [],
#  'Need to read documentation thoroughly': [],
#  'Getting the most from work': ['Alain De Botton'],
#  'Trend to immediacy': ['New Tab page is valuable real estate'],
#  "Linda can't get paid through upwork": [],
#  'NLP': ['Incredex'],
#  'DD Cardiogram': [],
#  'Geometric Game AI': [],
#  'Talking with Linda': [],
#  'Trying Psilocybin': [],
#  'Meetings with Harish': [],
#  'Idea engines come from disparate pieces': [],
#  'Reckful': [],
#  'Raghubir Singh': [],
#  'Ilumivu goals by January 31': [],
#  'Blender Low Poly Tricks': [],
#  'Feedback for Tom': [],
#  'Personal Brand and Persona': [],
#  'Kotlin quirks': [],
#  'Alexithymia': [],
#  'Eink Browser': [],
#  'Financial Updates': [],
#  'How total war can be improved': [],
#  'Kingrinder K4': [],
#  "hypotheses just aren't that important": ['Where do creative ideas come from?'],
#  'Teflon is an example of perverse corporate action': [],
#  'TikTok is great for building a young audience': [],
#  'Clarify context before giving feedback': [],
#  'My Notes System': ['Daily notes should be on paper'],
#  'Online enlightenment salons': [],
#  'Good habits come from generosity and strong rails': [],
#  'Marketing Agency Decision': [],
#  'Sperm Whale Facts': [],
#  'The General Commands': [],
#  'Analytics for websites are tricky': [],
#  'Setting Growth Goals': [],
#  'Reference Google Engine': [],
#  'Naval': [],
#  'Working With Tom': [],
#  'CX Meetings': [],
#  'Ancient Autometa': [],
#  'ACW Portable Wargame Variant': [],
#  'Andy Tech Setup': [],
#  'Flair': ['Coffee'],
#  'Where meaning comes from in every day life': [],
#  'Niche online communities are blooming': ['Finding good working groups'],
#  'Climate Crisis': [],
#  'Personalized web': ['The web has been neutered in terms of personalized discovery',
#   'New Tab page is valuable real estate'],
#  'Buy and Shopping list': [],
#  'Working Commitment': [],
#  'How to schedule and prioritize work appropriately': [],
#  'Cardiogram but better': [],
#  'Illumivu DD': ['Due Diligence'],
#  'Borderline Personality Disorder': ['Reckful'],
#  'Human Condition': ['Where meaning comes from in every day life',
#   'Kapil Gupta'],
#  'DNS Personal retro': [],
#  'Korean': [],
#  'I can enjoy helping others have fun': [],
#  'Startup Funding': [],
#  'Illumivu Marketing Kickoff': [],
#  'Deep Work': ['Cal Newport',
#   'Bird in the hand',
#   'I tried querying about creativity and idea generation in a few gardens'],
#  'Merger Aftermath': [],
#  'Test Tracks': [],
#  'Suprising notes are creative notes': ['Where do creative ideas come from?'],
#  'Purchase Checklist': [],
#  'Email Security': [],
#  'Colors': [],
#  'Dishwashers': [],
#  "So Good They Can't Ignore You": [],
#  'AGN Marketing Kickoff': [],
#  'Legal "Requirements"': [],
#  'Engage good opportunities': ['Have an engagement oriented mindset'],
#  "Tom's hiring process": [],
#  'Modern Skirmish Wargame Rules': [],
#  'Lin Manuel Miranda appeals to the modern everyman': [],
#  'Link Prediction': ['Bipartite graphs have sets that intra connect'],
#  'Bird in the hand': ['Focus makes everything better'],
#  'Document similarity is a multi-stage process': [],
#  'Subscriptions that I pay for': [],
#  'Word Embeddings': ['Document Similarity'],
#  'Evil Lobbying': [],
#  'VP Engineering Books': [],
#  'Adjacent Opportunities': ['Bird in the hand',
#   'Conventions bias research efforts',
#   'Focus makes everything better'],
#  'Mango and mayo in shrimp tacos': [],
#  'Once a day apps': [],
#  'Coffee': [],
#  'XGBoost': [],
#  'The democratic process is weak': [],
#  'Testing an ML Model': [],
#  'Procrastination Monkey': [],
#  'Online monetization without ads': [],
#  'The Book of Why': ['The Beginning of Infinity'],
#  'root': [],
#  'My focus areas': ['Idea engines come from disparate pieces'],
#  'Wabi Sabi': [],
#  'TikTok algorithm recommender': ['Sell shovels strategy'],
#  'Alan': [],
#  'Talking With Harish': [],
#  'Linda': [],
#  'Going on trips': [],
#  "You're not above the hype train": ['Engage good opportunities',
#   'Finding good working groups'],
#  'Management Culture': [],
#  'Anonymized ML training': [],
#  'How to upgrade small talk': [],
#  'When Hurt by Someone': [],
#  'Obsidian': ['My Notes System'],
#  'Have an engagement oriented mindset': ['Finding good working groups'],
#  'Saving links is bad': ['Reading effectively'],
#  'Piano': [],
#  'Mark Tech Gee Whiz Meetings': [],
#  'Camping Shit': [],
#  'Incredex': ['Link Prediction',
#   'plugins to improve obsidian',
#   'How to build collaborative web apps'],
#  'Durand filter coffee is standard darkish roast.': ['Coffee'],
#  'Web and Marketing': [],
#  '3D Print Figures': [],
#  'Python Shit': [],
#  'Bill Bates': [],
#  "It's very hard to understand how to contribute to causes I believe in": [],
#  'Foaming Milk': [],
#  'Time Chunking': [],
#  'Stuff to 3D pPrint': [],
#  'Spectrums of effective learning': ['Tiers of effective learning'],
#  'plugins to improve obsidian': ['root'],
#  'Cardiogram Marketing': [],
#  'The perfect design in yin yang': [],
#  'Linking notes is easier with a multi-note interface': [],
#  'Perfect House': [],
#  'Leanplum': [],
#  'If tests are failing or changing behavior based on order they run in.': [],
#  'Career': [],
#  'Ikigai': ['Where meaning comes from in every day life', 'Career', 'Dharma'],
#  'Espresso makes bad beans taste better': [],
#  '3D Print Design Ideas': [],
#  'Sapolsky says human behavior is determined on a spectrum of time and sources': [],
#  'Continued Merger Meetings': [],
#  'Ilumivu closing': [],
#  'Build an engaged work environment': [],
#  'One Habit Way': ['root', 'root', 'How to build collaborative web apps'],
#  'Positivity': [],
#  'Top of mind dev support resources': [],
#  'Public APIs and Data': [],
#  'Board Games': [],
#  'Using Obsidian as CMS and publishing easier and faster': [],
#  'ML Injection Attacks': ['Semantic Search is being explored slowly'],
#  'Ilumivu Marketing Meeting': [],
#  'Project Strategies': [],
#  'War Profiteering': [],
#  'Setting up Github for an Old Project': [],
#  'blue jay': [],
#  'Subitize': [],
#  'Low code is causing websites and apps to converge': [],
#  "David Li's Missisauga Address": [],
#  'Ideas are an output from an innovative process': ['innovation is iteration'],
#  'Startup Culture': [],
#  'Watch List': [],
#  'HyperPortable Hangboards': [],
#  'Hiring At Ilumivu': [],
#  'Zettelkasten': ['Obsidian'],
#  'Starting a campfire takes more tinder and kindling than expected': [],
#  'Castle Ravenloft': [],
#  'East vs west and individualism vs the group': ['Is creativity personal or collaborative?'],
#  'Ilumivu business sales learnings': [],
#  'Anxious Ambivalent Avoidant Attachment': [],
#  'Confidence': ['Alexithymia'],
#  'Sell shovels strategy': [],
#  'Managing Python Stuff': [],
#  'Air Conditioning': [],
#  'Designing Data Intensive Applications': [],
#  'Baking Pizza': [],
#  'Try making my home page query oriented': [],
#  'Double Standards': [],
#  'Jordan Peterson': [],
#  'Working with Tom Hiring': [],
#  'Dharma': ['Where meaning comes from in every day life', 'Career', 'Ikigai'],
#  'Tom Hiring': [],
#  'Is creativity personal or collaborative?': [],
#  'Random things to look up': [],
#  'Coding Basics': [],
#  'Where do creative ideas come from?': [],
#  'Youtube science debates': [],
#  'Purpose': [],
#  'Health EHeart Meeting': [],
#  'Due Diligence': [],
#  'Ilumivu Study Plan': [],
#  'Leslie Foods': [],
#  'Fictional romances': [],
#  'Conventions bias research efforts': ['The Book of Why'],
#  'Kapil Gupta': [],
#  'DNS retro': [],
#  'Catch Up Interview': [],
#  '3D Print Board Games': [],
#  'My Relationship Compatibility': [],
#  'A16Z': [],
#  'Book First Lines': [],
#  "You don't know yourself until you write it down": [],
#  'Correct PM Behavior': [],
#  'Georgia is taking on Hollywood': [],
#  'General software architecture concepts': [],
#  'Leaders help proactively': [],
#  'Utility Software I use': ['Subscriptions that I pay for'],
#  'Personality Change': [],
#  'More Ilumivu Meetings': [],
#  'The world is value based': ['Time Chunking'],
#  'Sides of Stories': [],
#  'The Beginning of Infinity': [],
#  'Young people struggle with basic life mechanics': [],
#  'Meeting with Sandeep on Offer': [],
#  'Design Review': [],
#  'Bipartite graphs have sets that intra connect': [],
#  'Pattio': [],
#  'Dream about flying through a pokemon world': [],
#  'Final fantasy password': [],
#  'Founder Material': [],
#  'Engineering leaders can serve the rest of the company': [],
#  'Disaster Recovery': [],
#  'Backlog of things to do': [],
#  'Software Books': [],
#  'Cardiogram Premium Conversion': [],
#  'Dubai': [],
#  'New Numbers Ilumivu': [],
#  'Meta Rules Game AI': [],
#  'Farmland being bought up': [],
#  "Cardiogram can't manage to sell its value": [],
#  'New Tab page is valuable real estate': [],
#  'Hiring John Norback': [],
#  'Always configure auto setup for terminal tools': [],
#  'John Norback': [],
#  'Balancing a game with diverse actions and units': [],
#  'Harish': [],
#  'My computer setup': [],
#  'How to Effectively Test Product Hypotheses': [],
#  'Doing art fast': [],
#  'Aversion to Account Making': [],
#  'Tiers of effective learning': ['Reading effectively'],
#  'Influence, Corporations, and Trust': [],
#  'Important data lake parameters': [],
#  'Leslie': [],
#  'Finding good working groups': ['root'],
#  'DD SAGE': [],
#  'Dark roasts need lower temp water, coarser grind, and shorter ratio': [],
#  'Unfocused design is bad design': [],
#  'Meta improvement is often a red herring': ['Where do creative ideas come from?'],
#  'Cognitive Dissonance during arguments': [],
#  'Just write it out': [],
#  'Management Meetings': [],
#  'Working Hard': [],
#  'A proper support ticketing system is important': [],
#  'Meeting With Sandeep': [],
#  'My habit guidance': [],
#  'Othismos': ['root'],
#  'Weaknessess': [],
#  'Purchase Log': [],
#  'Artists to Copy': [],
#  'build online presence': ['Analytics for websites are tricky'],
#  'Platforms move faster than protocols': ['The web has been neutered in terms of personalized discovery'],
#  'Semantic Search is being explored slowly': [],
#  'Immune System': [],
#  'Process improvements should be migrated lazily': [],
#  'Leslie Music': [],
#  'DD mEMA': [],
#  'Manuel': [],
#  'CRDT': ['How to build collaborative web apps'],
#  "House of Java's espresso is not good": [],
#  'Meat Industry Monopolies': [],
#  'Examples of Side Revenue': [],
#  'Heaters': [],
#  'Investing': [],
#  'Linked notes are better for yourself than others': ['Learning to write in a linked way is different'],
#  'Research needs to be spiked': [],
#  'Learning to write in a linked way is different': [],
#  'Negotiating Employment with Ilumivu': [],
#  'General Management Tips': [],
#  'I tried querying about creativity and idea generation in a few gardens': ['Linked notes are better for yourself than others'],
#  'Daily notes should be on paper': [],
#  'Cooking': [],
#  'GDPR': [],
#  'Learning and Achievement': ['Kapil Gupta'],
#  'Leanplum Tracking User Events': [],
#  'People want what others want': [],
#  'Differential Diagnosis': [],
#  'ML Model selection': [],
#  'How to build collaborative web apps': [],
#  'Flying Travel Packing': [],
#  'Stoicism': [],
#  'Robusta not neccessarily bad tasting': [],
#  'Maylynn': [],
#  'Focus makes everything better': ['Finding good working groups'],
#  'Ilumivu Engagement': [],
#  'How societies deal with stress and toxic competition': [],
#  "Simpson's Paradox results in counter intuitive results": [],
#  'Try to get something out of every meeting': [],
#  'RICE': ['Idea engines come from disparate pieces'],
#  'Mimicry': ['The world is value based',
#   'How societies deal with stress and toxic competition'],
#  'Beyesian Reasoning': ['The Beginning of Infinity'],
#  'Black Swan': ['Learning and Achievement']}

# %% [markdown]
# Similar functionality exists in the API for wikilinks (e.g. `wikilinks_index`, `get_wikilinks`)

# %% [markdown]
# What are the embedded files in Sussudio?

# %%
vault.get_embedded_files('Sussudio')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ps/k24lbqvs5q11gxbg_qhzykz40000gn/T/ipykernel_92970/634179674.py in <module>
# ----> 1 vault.get_embedded_files('Sussudio')
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/obsidiantools/api.py in get_embedded_files(self, file_name)
#     322
#     323         if file_name not in self._file_index:
# --> 324             raise ValueError('"{}" does not exist so it cannot have embedded files.'.format(file_name))
#     325         else:
#     326             return self._embedded_files_index[file_name]
#
# ValueError: "Sussudio" does not exist so it cannot have embedded files.

# %% [markdown]
# ### 5. What are the tags and front matter in notes?

# %% [markdown]
# By default the embedded files are not shown in the Obsidian graph, but there is an option to show them in the graph of a vault.  Currently that capability is not supported in `obsidiantools`; only the default behaviour is supported.

# %% [markdown]
# Load the front matter for Sussudio parsed as a dict:

# %%
vault.get_front_matter('Sussudio')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ps/k24lbqvs5q11gxbg_qhzykz40000gn/T/ipykernel_92970/180214015.py in <module>
# ----> 1 vault.get_front_matter('Sussudio')
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/obsidiantools/api.py in get_front_matter(self, file_name)
#     365             raise AttributeError('Connect notes before calling the function')
#     366         if file_name not in self._file_index:
# --> 367             raise ValueError('"{}" does not exist so it cannot have front matter.'.format(file_name))
#     368         else:
#     369             return self._front_matter_index[file_name]
#
# ValueError: "Sussudio" does not exist so it cannot have front matter.

# %% [markdown]
# In Sussudio note, the tag #`y1982` appears twice.  The order of appearance in their output from `get_tags()` is based on their order in the note content:

# %%
vault.get_tags('Sussudio')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ps/k24lbqvs5q11gxbg_qhzykz40000gn/T/ipykernel_92970/2834262456.py in <module>
# ----> 1 vault.get_tags('Sussudio')
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/obsidiantools/api.py in get_tags(self, file_name)
#     387             raise AttributeError('Connect notes before calling the function')
#     388         if file_name not in self._file_index:
# --> 389             raise ValueError('"{}" does not exist so it cannot have tags.'.format(file_name))
#     390         else:
#     391             return self._tags_index[file_name]
#
# ValueError: "Sussudio" does not exist so it cannot have tags.

# %% [markdown]
# ## Visualise your vault

# %% [markdown]
# The Obsidian app should be where you explore your vault visually, for all the interactive benefits!
#
# If you want to do network analysis of your vault, or else focus on a subgraph, then you can do analysis through the NetworkX graph object: `vault.graph`

# %%
color_cat_map = {False: '#D3D3D3', True: '#826ED9'}
color_vals = (df['note_exists']
              .map(color_cat_map)
              .values)

# %% [markdown]
# The notes in the graph below are purple if they have a markdown file.
#
# - <span><img src="https://via.placeholder.com/15/826ED9/000000?text=+#left" alt="alt_text" align="left"/>: Note exists as a file</span>
# - <span><img src="https://via.placeholder.com/15/D3D3D3/000000?text=+#left" alt="alt_text" align="left"/>: Note doesn't exist as a file </span>

# %%
fig, ax = plt.subplots(figsize=(13,7))
nx.draw(vault.graph, node_color=color_vals, with_labels=True, ax=ax)
ax.set_title('Vault graph')
plt.show()

# %% [markdown]
# ### Graph analysis

# %% [markdown]
# Where `obsidiantools` has the potential to be really powerful in your Obsidian workflows is its linkage with the sophisticated graph analysis capabilities of NetworkX.

# %% [markdown]
# There are many algorithms that you can use to analyse the **centrality** of nodes in a graph in NetworkX.

# %% [markdown]
# Let's look at the **PageRank** of notes in the vault.  Google has used PageRank to rank the importance of search engine results.
#
# As outlined by Google:
#
# >The underlying assumption is that more important websites are likely to receive more links from other websites
#
# In the **Obsidian** realm, the notes that would be ranked highest by PageRank are the 'notes likely to receive more links from other notes', i.e. the notes that have **backlinks from a broad range of notes**.
#
# Let's see this in action.

# %%
(pd.Series(nx.pagerank(vault.graph), name='pagerank')
 .sort_values(ascending=False))
# Out:
# Dharma                                                                    0.026671
# Ikigai                                                                    0.026671
# Word Embeddings                                                           0.011707
# Document Similarity                                                       0.010974
# Deep Work                                                                 0.010240
# NLP                                                                       0.010111
# Adjacent Opportunities                                                    0.009577
# Incredex                                                                  0.009097
# Mimicry                                                                   0.008137
# Ideas are an output from an innovative process                            0.007991
# Zettelkasten                                                              0.007577
# You're not above the hype train                                           0.006911
# innovation is iteration                                                   0.006603
# I tried querying about creativity and idea generation in a few gardens    0.006116
# Obsidian                                                                  0.006116
# Personalized web                                                          0.005503
# Conventions bias research efforts                                         0.005257
# Spectrums of effective learning                                           0.005257
# Black Swan                                                                0.005257
# The web has been neutered in terms of personalized discovery              0.004977
# economic success is driven by channels and innovation equally             0.004971
# Engage good opportunities                                                 0.004791
# Platforms move faster than protocols                                      0.004493
# ML Injection Attacks                                                      0.004398
# Utility Software I use                                                    0.004398
# The world is value based                                                  0.004398
# Confidence                                                                0.004398
# My Notes System                                                           0.004398
# East vs west and individualism vs the group                               0.004398
# Link Prediction                                                           0.004398
#                                                                             ...
# 3D Print Board Games                                                      0.002377
# My Relationship Compatibility                                             0.002377
# A16Z                                                                      0.002377
# Book First Lines                                                          0.002377
# You don't know yourself until you write it down                           0.002377
# Correct PM Behavior                                                       0.002377
# Georgia is taking on Hollywood                                            0.002377
# General software architecture concepts                                    0.002377
# Leaders help proactively                                                  0.002377
# Personality Change                                                        0.002377
# Ilumivu Study Plan                                                        0.002377
# Health EHeart Meeting                                                     0.002377
# Anxious Ambivalent Avoidant Attachment                                    0.002377
# Purpose                                                                   0.002377
# Sell shovels strategy                                                     0.002377
# Managing Python Stuff                                                     0.002377
# Air Conditioning                                                          0.002377
# Designing Data Intensive Applications                                     0.002377
# Baking Pizza                                                              0.002377
# Try making my home page query oriented                                    0.002377
# Double Standards                                                          0.002377
# Jordan Peterson                                                           0.002377
# Working with Tom Hiring                                                   0.002377
# Tom Hiring                                                                0.002377
# Is creativity personal or collaborative?                                  0.002377
# Random things to look up                                                  0.002377
# Coding Basics                                                             0.002377
# Where do creative ideas come from?                                        0.002377
# Youtube science debates                                                   0.002377
# Marketing Learning                                                        0.002377
# Name: pagerank, Length: 337, dtype: float64

# %% [markdown]
# - `Caelum` has the highest rank in the main graph.  It has 3 backlinks from 3 notes.
# - These notes have 0 backlinks and rank very low as a result:
#     - `Isolated note` (of course!)
#     - `Vulnera ubera`
#     - `Alimenta`
#     - `Sussudio`
# - `Bacchus` has the most backlinks (5), but doesn't rank highest!  Why might that be?  Well, the quality of those backlinks are questionable.  There are 4 backlinks to the note from `Alimenta`, which has 0 backlinks.  See further analysis below on what those backlinks look like.

# %% [markdown]
# #### Low-quality backlinks

# %% [markdown]
# This is a peek at the plaintext of the files, which are only accessible after the GATHER function is called.  All the text is stored in the `text_index` of the vault.

# %%
last_lines_alimenta = (vault.get_text('Alimenta')
                       .splitlines()[-5:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ps/k24lbqvs5q11gxbg_qhzykz40000gn/T/ipykernel_92970/2792754344.py in <module>
# ----> 1 last_lines_alimenta = (vault.get_text('Alimenta')
#       2                        .splitlines()[-5:])
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/obsidiantools/api.py in get_text(self, file_name)
#     411             raise AttributeError('Gather notes before calling the function')
#     412         if file_name not in self._file_index:
# --> 413             raise ValueError('"{}" does not exist so it cannot have text.'.format(file_name))
#     414         else:
#     415             return self._text_index[file_name]
#
# ValueError: "Alimenta" does not exist so it cannot have text.

# %%
for l in last_lines_alimenta:
    print(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ps/k24lbqvs5q11gxbg_qhzykz40000gn/T/ipykernel_92970/4202395720.py in <module>
# ----> 1 for l in last_lines_alimenta:
#       2     print(l)
#
# NameError: name 'last_lines_alimenta' is not defined

# %% [markdown]
# Here we can see that there are a few repetitive wikilinks to `Bacchus` at the end of the file.  As it happens, all the other notes in this vault only link to another note once.  This is where the quality of backlinks matter to PageRank: notes don't rank high if they pile up backlinks from one note.
